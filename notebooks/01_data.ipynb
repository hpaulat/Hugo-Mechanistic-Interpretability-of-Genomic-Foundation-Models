# %%
import os
import sys

# ensure relative paths resolve correctly
os.chdir("../external/genomic-FM")
sys.path.append(".")

from src.dataloader.data_wrapper import RealClinVar

loader = RealClinVar(num_records=100, all_records=False)
data = loader.get_data(Seq_length=1024)

print(len(data))
print(data[0])
